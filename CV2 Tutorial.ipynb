# %%
import cv2

# %%
img = cv2.imread("lion.jpg")

# %%
cv2.imshow("lion",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
blue,green,red = cv2.split(img)

# %%
cv2.imshow("Blue",blue)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("Red",red)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("Green",green)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("Blue.png",blue)
cv2.imwrite("Red.png",red)
cv2.imwrite("Green.png",green)
# Out:
# True

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.imshow(img[:,:,-1])

# %%
img1 = plt.imshow(img, cmap="gray")

# %%
img2 = cv2.flip(img,0)

# %%
cv2.imshow("img2",img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
d = cv2.vconcat([img,img2])

# %%
cv2.imshow("d",d)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("WaterEffectLion.jpeg",d)
# Out:
# True
